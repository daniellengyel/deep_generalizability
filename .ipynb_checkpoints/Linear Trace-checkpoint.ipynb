# %%
import pandas as pd
import pickle,os, copy
import matplotlib.pyplot as plt
import torch
from torch.utils.data import DataLoader
import sys


import re

from sklearn.cluster import DBSCAN


from deep_generalizability.nets import Nets
from deep_generalizability.utils import *
from deep_generalizability.postprocessing.postprocessing import *
from deep_generalizability.postprocessing.stats_plotting import *
from deep_generalizability.save_load import *

from deep_generalizability.postprocessing.sharpness_measures import *
from deep_generalizability.postprocessing.stats_plotting import *

from deep_generalizability.data_getters import *

# %load_ext autoreload
# %autoreload 2

plt.rcParams["figure.figsize"] = (13,9)

# %%
root_folder = os.environ["PATH_TO_DEEP_FOLDER"]
data_name = "gaussian"
exp = "Aug26_17-12-39_Daniels-MacBook-Pro-4.local"
experiment_folder = os.path.join(root_folder, "experiments", data_name, exp)

# %%
stats_df = get_end_stats(experiment_folder)

# %%
stats_df.sort_values(by="Acc Test Max", ascending=False)
# Out:
#                     Acc Gap Mean  Acc Test Max  Acc Test Mean  Acc Test Min  \
# 1598454775.5546958         0.013           0.5            0.5           0.5
# 1598454775.55614           0.013           0.5            0.5           0.5
# 1598454775.554893          0.013           0.5            0.5           0.5
# 1598454775.557622          0.013           0.5            0.5           0.5
# 1598454775.553455          0.013           0.5            0.5           0.5
# 1598454775.549441          0.013           0.5            0.5           0.5
# 1598454775.642882          0.013           0.5            0.5           0.5
# 1598454775.553566          0.013           0.5            0.5           0.5
# 1598454775.813365          0.013           0.5            0.5           0.5
# 1598454775.5537322         0.013           0.5            0.5           0.5
#
#                     Acc Train Max  Acc Train Mean  Acc Train Min  \
# 1598454775.5546958          0.487           0.487          0.487
# 1598454775.55614            0.487           0.487          0.487
# 1598454775.554893           0.487           0.487          0.487
# 1598454775.557622           0.487           0.487          0.487
# 1598454775.553455           0.487           0.487          0.487
# 1598454775.549441           0.487           0.487          0.487
# 1598454775.642882           0.487           0.487          0.487
# 1598454775.553566           0.487           0.487          0.487
# 1598454775.813365           0.487           0.487          0.487
# 1598454775.5537322          0.487           0.487          0.487
#
#                     Loss Test Max  Loss Test Mean  Loss Test Min  \
# 1598454775.5546958       1.000808        1.000808       1.000808
# 1598454775.55614         1.000081        1.000081       1.000081
# 1598454775.554893             NaN             NaN            NaN
# 1598454775.557622        1.012183        1.012183       1.012183
# 1598454775.553455        1.050949        1.050949       1.050949
# 1598454775.549441        1.098983        1.098983       1.098983
# 1598454775.642882        1.000339        1.000339       1.000339
# 1598454775.553566        1.000284        1.000284       1.000284
# 1598454775.813365        1.000209        1.000209       1.000209
# 1598454775.5537322       1.000612        1.000612       1.000612
#
#                     Loss Train Max  Loss Train Mean  Loss Train Min  Norm Max  \
# 1598454775.5546958        1.000707         1.000707        1.000707  0.039326
# 1598454775.55614          1.000158         1.000158        1.000158  0.040614
# 1598454775.554893              NaN              NaN             NaN       NaN
# 1598454775.557622         1.015118         1.015118        1.015118  0.219344
# 1598454775.553455         1.061057         1.061057        1.061057  0.438247
# 1598454775.549441         1.118353         1.118353        1.118353  0.579467
# 1598454775.642882         1.000033         1.000033        1.000033  0.023062
# 1598454775.553566         1.000218         1.000218        1.000218  0.022441
# 1598454775.813365         1.000085         1.000085        1.000085  0.022908
# 1598454775.5537322        1.000089         1.000089        1.000089  0.030358
#
#                     Norm Mean  Norm Min learning_rate
# 1598454775.5546958   0.039326  0.039326    0.00215443
# 1598454775.55614     0.040614  0.040614      0.359381
# 1598454775.554893         NaN       NaN             1
# 1598454775.557622    0.219344  0.219344   0.000774264
# 1598454775.553455    0.438247  0.438247   0.000278256
# 1598454775.549441    0.579467  0.579467        0.0001
# 1598454775.642882    0.023062  0.023062      0.016681
# 1598454775.553566    0.022441  0.022441     0.0464159
# 1598454775.813365    0.022908  0.022908      0.129155
# 1598454775.5537322   0.030358  0.030358    0.00599484

# %%
from deep_generalizability.training import *

# %%
net = LinearNet(2, 1)
data = get_data(gaussian, vectorized=True,
                                  meta=config["data_meta"])
training_step(net, iter_data_loader, optimizer, criterion, var_noise=None, writer=None, curr_step=-1, idx_net=-1, device=None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-8236df178763> in <module>
#       1 net = LinearNet(2, 1)
#       2
# ----> 3 training_step(net, iter_data_loader, optimizer, criterion, var_noise=None, writer=None, curr_step=-1, idx_net=-1, device=None)
#       4
#
# NameError: name 'training_step' is not defined

# %%
point_traces, meta = load_cached_data(experiment_folder, "point_traces", step=-1)

# %%
margin_filters = get_exp_margins(experiment_folder, softmax_outputs=False, step=-1, seed=0, device=None, num_datapoints=100, on_test_set=False, should_cache=False)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-32-07dd9ac279eb> in <module>
# ----> 1 margin_filters = get_exp_margins(experiment_folder, softmax_outputs=False, step=-1, seed=0, device=None, num_datapoints=100, on_test_set=False, should_cache=False)
#
# ~/deep_generalizability/deep_generalizability/postprocessing/postprocessing.py in get_exp_margins(experiment_folder, softmax_outputs, step, seed, device, num_datapoints, on_test_set, should_cache)
#     235
#     236         models_dict = get_models(curr_path, step)
# --> 237         margins_dict[exp_name] = get_margins_filters(models_dict, data, device=device, softmax_outputs=softmax_outputs, seed=seed)
#     238
#     239         # cache data
#
# ~/deep_generalizability/deep_generalizability/postprocessing/margins.py in get_margins_filters(models, data, device, softmax_outputs, seed)
#     106
#     107         # if correctly predicted
# --> 108         second_largest = torch.topk(outputs, k=2, dim=1)
#     109
#     110         curr_margins = second_largest[0][:, 0] - second_largest[0][:, 1]
#
# RuntimeError: selected index k out of range

# %%
linear_loss_trace_filters = get_exp_linear_loss_trace(experiment_folder, step=-1, seed=0, device=None, num_datapoints=100, on_test_set=False, should_cache=False)

# %%
# Plot trace vs margins
X_axis_name = "Analytics Linear Trace"
Y_axis_name = "Hessian Trace"


plot_name = "Correct_Incorrect"
X_axis_bounds = None
Y_axis_bounds = None

save_exp_path = None

filter_seperate = ["learning_rate"]
filter_not_seperate = None

pre_filtered_exp_ids = None

use_correct_filter = True

data_func = margin_trace_correct_incorrect_plot(linear_loss_trace_filters, point_traces, use_correct_filter=use_correct_filter)

hp_data_func_plot(experiment_folder, data_func, X_axis_name, Y_axis_name, 
                  plot_name, filter_seperate, filter_not_seperate,
                 save_exp_path, X_axis_bounds, Y_axis_bounds, 
                    pre_filtered_exp_ids)
